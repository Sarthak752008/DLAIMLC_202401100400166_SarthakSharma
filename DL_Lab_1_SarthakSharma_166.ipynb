# %% [markdown]
# # Tensorflow

# %%
import tensorflow as tf
import numpy as np

x = np.array([1,2,3,4], dtype=float)
y = np.array([2,4,6,8], dtype=float)

model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='sgd', loss='mean_squared_error')

model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - loss: 79.9695
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 55.5388
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 38.5866
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 26.8235
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 18.6610
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 12.9970
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 9.0665
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 6.3390
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.4461
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3.1324

# %% [markdown]
# # Keras

# %%
import numpy as no
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([1,2,3,4], dtype=float)
y = np.array([2,4,6,8], dtype=float)

model = Sequential([
    Dense(1, input_shape=(1,))
])

model.compile(optimizer='sgd', loss='mean_squared_error')

model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 1.0569
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.7340
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.5100
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3545
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2466
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1718
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1198
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0838
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0588
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0414

# %% [markdown]
# # Pytorch

# %%
import torch
import torch.nn as nn
import torch.optim as optim

#Define a simple linear model
model = nn.Linear(1, 1)

#Loss and optimizer
criterian = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = 0.01)

#Dummy data
x = torch.tensor([[1, ], [2, ], [3, ], [4, ]], dtype=torch.float32) # Changed to float32
y = torch.tensor([[2, ], [4, ], [6, ], [8, ]], dtype=torch.float32) # Changed to float32

#Training loop
for epoch in range(10) :
  optimizer.zero_grad()
  outputs = model(x)
  loss = criterian(outputs, y)
  loss.backward()
  optimizer.step()
  print(f'Epoch {epoch + 1}, Loss: {loss.item()}')
# Out:
# Epoch 1, Loss: 37.677879333496094
# Epoch 2, Loss: 26.271831512451172
# Epoch 3, Loss: 18.356647491455078
# Epoch 4, Loss: 12.863714218139648
# Epoch 5, Loss: 9.051525115966797
# Epoch 6, Loss: 6.405576705932617
# Epoch 7, Loss: 4.5688629150390625
# Epoch 8, Loss: 3.2936630249023438
# Epoch 9, Loss: 2.4080915451049805
# Epoch 10, Loss: 1.7928777933120728
